# %%
import pydicom
import cv2
import matplotlib.pyplot as plt

# %%
video1 = pydicom.dcmread('/home/shokoo/EchoView/video_class/Tahseen/_3wRyUbdSGmjEWULRVg-jw/2').pixel_array
video2 = pydicom.dcmread('/home/shokoo/EchoView/video_class/Tahseen/_3wRyUbdSGmjEWULRVg-jw/27').pixel_array

# %%
def visualization(image):
    plt.figure(figsize=(8,10))
    plt.imshow(image)
    plt.show()

# %%
for i in range(0,10,2):
    visualization(video2[i,:,:])

# %%
visualization((video2[2,:,:,2] == video2[2,:,:,1]))
